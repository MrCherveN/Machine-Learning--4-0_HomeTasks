# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCherveN/Machine-Learning--4-0_HomeTasks/blob/main/HW5_%D0%A6%D0%B8%D0%BA%D0%BB_while_List_comprehensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Цикл while**
#
# Задано змінну `counter`, яка рівна -3.
#
# Напишіть програму, використовуючи `while`, яка в циклі додає до змінної `counter` +1 і зупиняється, коли змінна `counter` стане суворо більше за 5. На кожній ітерації циклу виводьте значення змінної `counter`.

# %% [markdown]
# Відповідь: не зовсім зрозуміло, в який саме момент ітерації повинен спрацювати вивід, тому зробив два варінти. На перший погляд варінт №1 більше відповідає умові завдання.

# %%
counter = -3

# Варіант з print() граничного обмеження, але без початкового значення.
while counter < 5:
  counter += 1
  print(counter)
# Out:
# -2
# -1
# 0
# 1
# 2
# 3
# 4
# 5

# %%
counter = -3

# Варіант з print() без граничного обмеження, але з початковим значенням
while counter < 5:
  print(counter)
  counter += 1
# Out:
# -3
# -2
# -1
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ---
#
# **2. List comprehension - прості операції**
#
# Дано список чисел:

# %%
numbers = [11, 4, 9, 16, 7, 5]

# %% [markdown]
# Створіть нові списки використовуючи list comprehension, які містять (кожен пункт оцінюється в 0.5 бала):
# - Квадрати всіх чисел
# - Тільки парні числа
# - Всі числа помножені на 10
#
# Виведіть новоутворені списки.

# %%
list_1 = [i**2 for i in numbers]
print(f'{list_1}')

list_2 = [i for i in numbers if i % 2 == 0]
print(f'{list_2}')

list_3 = [i * 10 for i in numbers]
print(f'{list_3}')
# Out:
# [121, 16, 81, 256, 49, 25]
# [4, 16]
# [110, 40, 90, 160, 70, 50]

# %% [markdown]
# ---
#
# **3. List comprehension - комбінована логіка**
#
# Дано список чисел від 1 до 10. Створіть новий список, де виконується наступна логіка:
# - Якщо число парне - помножте його на 2
# - Якщо непарне - віднімніть 1
#
# Виведіть результуючий список на екран.

# %%
numbers = list(range(1, 11))

# %%
new_numbers = [i * 2 if i % 2 == 0 else i -1 for i in numbers]
print(new_numbers)
# Out:
# [0, 4, 2, 8, 4, 12, 6, 16, 8, 20]
